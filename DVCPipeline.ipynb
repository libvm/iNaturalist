# %%
# !pip install dvc
# !pip install dvclive
# !pip install dvc[gs]
# !pip install dvc-gdrive
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.1/457.1 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.0/426.0 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !dvc init
# Out:
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/iterative/dvc>

# %%
# !dvc remote add -d gdrive gdrive://1HUdes4gE9Q_VMOFAGVv2TVbg_qNF2Q4p
# Out:
# Setting 'gdrive' as a default remote.

# %%
# !dvc remote modify gdrive gdrive_use_service_account true
# !dvc remote modify gdrive --local gdrive_service_account_json_file_path /content/solid-shelter-445518-q9-d946a3159012.json

# %%
# !git config --global user.email "farhetka777@mail.ru"
# !git config --global user.name "libvm"

# %%
# !git add ./src
# !git add dvc.yaml
# !git add params.yaml
# !git commit -m "Initial commit"
# Out:
# [master (root-commit) 3d6df30] Initial commit
#  9 files changed, 393 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore
#  create mode 100644 dvc.yaml
#  create mode 100644 params.yaml
#  create mode 100644 src/download_data.py
#  create mode 100644 src/evaluate.py
#  create mode 100644 src/prepare_data.py
#  create mode 100644 src/train.py

# %%
# !dvc exp run --set-param "train.learning_rate=0.01"
# Out:
# Reproducing experiment 'pagan-vase'
# Building workspace index          |6.75k [00:00, 20.0kentry/s]
# Comparing indexes          |6.76k [00:00, 18.1kentry/s]
# WARNING: No file hash info found for '/content/models/model.pth'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/wolves'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/weasels'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/raccoons'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/hyenas'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/foxes'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/mongooses'. It won't be created.
# WARNING: No file hash info found for '/content/data_split/train/skunks'. It won't be created.
# ...

# %%
# !dvc exp run --set-param "train.learning_rate=0.001"
# Out:
# Reproducing experiment 'wroth-yips'
# Building workspace index          |13.5k [00:00, 23.3kentry/s]
# Comparing indexes          |13.5k [00:00, 16.5kentry/s]
# Applying changes          |0.00 [00:00,     ?file/s]
# Stage 'download' didn't change, skipping
# Stage 'prepare' didn't change, skipping
# Running stage 'train':
# > python src/train.py
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !dvc exp show
# Out:
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
# !dvc add ./models
# !dvc add ./images
# !dvc add ./data
# !dvc add ./data_split
# !dvc commit
# Out:
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# !
# Checking out /content/models          |0.00 [00:00,    ?files/s]
# Adding...: 100% 1/1 [00:00<00:00, 36.05file/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add .gitignore models.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
# 100% 4.10k/4.10k [00:00<00:00, 39.4kfile/s{'info': ''}]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# !
# Checking out /content/images          |0.00 [00:00,    ?files/s]
# Adding...: 100% 1/1 [00:00<00:00,  2.09file/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add .gitignore images.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# ...

# %%
# !dvc push
# Out:
# Streaming output truncated to the last 5000 lines.
# Pushing to gdrive:  52% 3.48k/6.72k [22:33<16:16, 3.32file/s{'info': ''}]
#
#
#
#
#
#   0% 0.00/53.0k [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/53.0k [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#
#
#  18% 8.00k/44.0k [00:00<00:03, 12.1kB/s{'info': ''}]
#
#
#
#
#
#
#
#   0% 0.00/52.9k [00:00<?, ?B/s]
#
#
#
#   0% 0.00/52.9k [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#  18% 8.00k/44.6k [00:00<00:03, 11.4kB/s{'info': ''}]
#
#
#
#
#
#  15% 8.00k/53.0k [00:00<00:03, 11.9kB/s{'info': ''}]
#
#
#
#  15% 8.00k/52.9k [00:00<00:04, 11.2kB/s{'info': ''}]
#
#
#
#
#
#
#
# Pushing to gdrive:  52% 3.49k/6.72k [22:35<29:20, 1.84file/s{'info': ''}]
#
#
#
#
#
#
#   0% 0.00/68.5k [00:00<?, ?B/s]
#
#
#
#
#
#
#   0% 0.00/68.5k [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0% 0.00/58.1k [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   0% 0.00/58.1k [00:00<?, ?B/s{'info': ''}]
#
#
#
#   0% 0.00/43.0k [00:00<?, ?B/s]
#
#   0% 0.00/43.0k [00:00<?, ?B/s{'info': ''}]
# ...

# %%
# !git add ./src
# !git add dvc.yaml
# !git add params.yaml
# !git add models.dvc
# !git add images.dvc
# !git add data.dvc
# !git add data_split.dvc
# !git commit -m "runs have been made with lr 0.01, 0.001"

# %%
# !git push origin main https://libvm:TOKEN@github.com/libvm/iNaturalist

# %%
# !git config --list

# %%
# !dvc plots diff 715c363 39639f8 --targets dvclive_loss/plots/metrics/val_acc.tsv --x-label acc
# Out:
# file:///content/dvc_plots/index.html
